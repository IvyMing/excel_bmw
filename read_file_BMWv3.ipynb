# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from win32com.client import DispatchEx
import os
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
import numpy as np


# import pdfkit
# import jpype
# import asposecells
# from asposecells.api import Workbook, FileFormatType, PdfSaveOptions
#import xlsxwriter

# %%
import string
alph = string.ascii_lowercase.upper()
#creat PDF file
def to_pdf(df2, path=None, filename="table"):

    if path == None:
        return
    wb = load_workbook(path)
    ws = wb.active
    
    dims = {}
    for row in ws.rows:
        for cell in row:
            if cell.value:
                dims[cell.column] = max((dims.get(cell.column, 0), len(str(cell.value))))    
    for col, value in dims.items():
        #print(col)
        ws.column_dimensions[alph[col-1]].width = value
    wb.save(filename=path)
#     column_widths = []
#     for row in data:
#         for i, cell in enumerate(row):
#             if len(column_widths) > i:
#                 if len(cell) > column_widths[i]:
#                     column_widths[i] = len(cell)
#             else:
#                 column_widths += [len(cell)]

#     for i, column_width in enumerate(column_widths,1):  # ,1 to start at 1
#         worksheet.column_dimensions[get_column_letter(i)].width = column_width
    
    
#     # Create and set PDF options
#     pdfOptions = PdfSaveOptions()
#     pdfOptions.setCompliance(PdfCompliance.PDF_A_1_B)

#     # Convert Excel to PDF
#     workbook.save(r'C:\Users\明\Desktop\BMW\{}.pdf'.format(filename), pdfOptions)
    excel_path = path
    pdf_path = r'U:\BMW\{}.pdf'
    #pdf_path = r'C:\Users\明\Desktop\BMW\{}.pdf'
    #pdf_path = r'C:\Users\明\Desktop\BMW\{}.pdf'
    df = DispatchEx("Excel.Application")
    df.Visible = False
    df.DisplayAlerts = 0
    books = df.Workbooks.Open(excel_path,False)
    books.ExportAsFixedFormat(0, pdf_path.format(filename))
    books.Close(False)
    df.Quit()

# %%
filename = r'U:\BMW\2022-04-04_10-16_beat_softwareverbund_I_K22_22-07_505_22w13_DE61.xlsx'
#filename = r'C:\Users\明\Desktop\BMW\2022-04-04_10-16_beat_softwareverbund_I_K22_22-07_505_22w13_DE61.xlsx'
sheetname = 'Funkt_und_Bewertung_n_Standort'

# %%
# DICTIONARY TO CLASSIFY GROUP BASED ON KEYWORDS
# keyword : GROUP

KEYWORDS = {
    #NAV
    "Display map ASIA" : "NAV",
    "POI Functions ASIA" : "NAV",
    "Manage and Plan Routes ASIA" : "NAV",
    "Navigation Destination Input ASIA" : "NAV",
    "Map and Navigation Data update ASIA" : "NAV",
    "Display map ASIA" : "NAV",
    "Traffic Info ASIA" : "NAV",
    "Guiding ASIA" : "NAV",
    "Positioning ASIA" : "NAV",
    "Guiding ASIA" : "NAV",
    "" : "NAV",
    "" : "NAV",
    #ENT
    "CarPlay" : "ENT",
    "Play audio via USB" : "ENT",
    "Display & operation in the rear of entertainment sources (BMT)" : "ENT",
    "Manage CE Devices (Bluetooth)" : "ENT",
    "Play audio via Bluetooth" : "ENT",
    "elephony via second customer device" : "ENT",
    "elephony via customer device" : "ENT",
    "Watch TV (Japan)" : "ENT",
    "Listen to AM/FM Radio (Legacy < IDC Android)" : "ENT",
    "Show Call List" : "ENT",
    "Display Contacts" : "ENT",
    "Search Contacts" : "ENT",
    "FireTV download of content" : "ENT",
    "Consumer e-SIM Management" : "ENT",
    "Display and operation of PaDi BMW widgets" : "ENT",
    "FireTV Full App Support and Automotive Feature Set" : "ENT",
    "FireTV VoD App and Audio Output" : "ENT",
    "Internet Access via Hotspot" : "ENT",
    "PaDi Remote Control via BMT" : "ENT",
    "PaDi RoW CE area (FireTV) bring-up" : "ENT",
    "PaDi View and Audio Settings" : "ENT",
    "Handsfree Telephony in the rear seats" : "ENT",
    "Telephony via customer SIM" : "ENT",
    "Display map ASIA" : "ENT",
    "" : "ENT",
    "" : "ENT",
    "" : "ENT",
    "" : "ENT",
    "" : "ENT",
    "" : "ENT",
    "" : "ENT",
    
    #HMI
    "Display of User Manual" : "HMI",
    "ZBE Control" : "HMI",
    "Augmented Reality Video CID" : "HMI",
    "Voice Interface" : "HMI",
    "Functional Bookmark Control" : "HMI",
    "Display Touch Control" : "HMI",
    "" : "HMI",
    "" : "HMI",
    #DIPS
    " E-Call" : "DIPS",
    "Call Customer service" : "DIPS",
    "Concierge Call" : "DIPS",
    "Voice Interface" : "DIPS",
    "OAP App platform Vehicle-App-Interface Setup" : "DIPS",
    "Remote Services" : "DIPS",
    "Report service issues via Teleservice" : "DIPS",
    "Transfer Data from Vehicle to Backend (Last State Call)" : "DIPS",
#     "" : "DIPS",
#     "" : "DIPS",
#     "" : "DIPS",
#     "" : "DIPS",
#     "" : "DIPS",
    
}

def group(x):
    for g in KEYWORDS.keys():
        if g in x:
            return KEYWORDS[g]
    return "Default"

# %%
#edit content
def remove_time(x):
    y = x.split("\n")
    if ":" in y[0]:
        y[0] = ":".join(y[0].split(':')[2:])
    elif " " in y[0]:
        y[0] = " ".join(y[0].split(' ')[2:])
    
    return "\n".join(y)

# def remove_MLI(x):
    
#     y = x.split("\n")
#     for i in y:
# #         print('i!!',i)
#         if i == '[MLI]':
#            MLI_index = y.index('[MLI]') 
#            if y[MLI_index + 1] == '':
# #                y.remove (y[MLI_index])
# #                y.remove (y[MLI_index+1])
#                 #y = (y[MLI_index:])
#                 y = (y[MLI_index+3:])
#         if i == 
#           y.remove(i)
#     return y

def remove_MLI2(x):
    
    #print('type',type(x))
    x = x.replace('[MLI]\n\n', '')
    #print('X_new', x)
    return x

def remove_TOP2(x):
    x = x.replace('[Top5 defects]\n\n', '')
    #print('X_new', x)
    return x
    

    
def remove_line(x):
    x = x.replace('–––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––', '')
    #print('X_new', x)
    return x

def remove_additional(x):
#     x = x.replace('[Additional information]\n\n\n\#1\n#2\n#3\n#4', '')
#     x = x.replace('[Additional information]\n\n\n#1\n#2\n#3', '')
#     x = x.replace('[Additional information]\n\n\n#1\n#2', '')
#     x = x.replace('[Additional information]\n\n\n#1\n#2', '')
#     x = x.replace('[#2\n#3\n#4\n#5\n#6\n#7\n#8]','')
    y = x.split("\n")
    for i in y:
        if i == '[Additional information]':
           # print("yyyyyyyyy",y[0:ADD_index])
            ADD_index = y.index('[Additional information]') 
            print("yyyyyyyyy",y[0:ADD_index])
            y = y[0:ADD_index]
            y = pd.DataFrame(y)
            return y
    #return x
#     for i in y:
#         if i == '#1':
#            a = y.index('#1') 
#            if y[a + 1] == '#2':
#                 y.remove (y[a])
#                 if y[a + 2] == '#3':
#                     y.remove (y[a+1])
# #                y.remove (y[MLI_index+1])
#                 #y = (y[MLI_index:])
#                 y = (y[a+2:])
        

def remove_space(x):
    x = x.replace('\n\n\n', '')
    #print('X_new', x)
    return x


def remove_colums(x):
#     print("!!!!!!!!!!x",x)
#     print("typeX",type(x))
#     print("!!!!!!!!!!x1",x[1])
#     for i in len(x):
#         print('len',len(str(x[i])))
#         if len(str(x[i])) <= 25:
#             print("!!!!!!!!",x[i])
#             x_new = x.drop(x[i])
    return x
        
# def remove_TOP(x):
   
#     y = x.split("\n")
#     for i in y:
#         if i == '[Additional information]\n#1':
#            MLI_index = y.index('[MLI]') 
#            if y[MLI_index + 1] == '':
# #                y.remove (y[MLI_index])
# #                y.remove (y[MLI_index+1])
#                 #y = (y[MLI_index:])
#                 y = (y[MLI_index+3:])
# def remove_top(x):
#     y = x.split("\n")
#     top_index = y.index('[Top5 defects]')
#     if y[top_index + 1] == '':
#        y.remove (y[top_index])
#        y.remove (y[top_index+1])
#     return y

#  def remove_words(x):
#     ticket = re.sub('[MLI]\n\n', x)

# %%
#iloc.style.hide_index()

# %%
# creat new Excel colum
data = pd.read_excel(filename,sheet_name=sheetname) 
#data.rename(columns={‘Name EN Reportelement’:‘A’,‘AIDA IP RG’:‘B’},inplace=True)

df = pd.DataFrame(data, columns= ['Name EN Reportelement','AIDA IP RG','Standort RG','Standort Bemerkung','Standort Name'])
#df = pd.DataFrame(data, columns= ['A','B','Standort RG','Standort Bemerkung','Standort Name'])

df = df[df['Standort Name'] == 'JAP']
#df['Name EN Reportelement'] = df['Name EN Reportelement'].rename('Name EN Reportelement':'name')
#groups = [group(x) for x in df['Name EN Reportelement']]
print('1,2@@@@@@@@@',df)
cols = df.columns.tolist()

cols = ["Domain"] + cols
df["Domain"] = groups
df = df[cols]

print('1,2@@@@@@@@@',df.iloc[0,2])


df['Standort Bemerkung'] = [remove_time(x) for x in df['Standort Bemerkung']]
print(df['Standort Bemerkung'])
df['Standort Bemerkung'] = [remove_MLI2(x) for x in df['Standort Bemerkung']]
df['Standort Bemerkung'] = [remove_TOP2(x) for x in df['Standort Bemerkung']]
df['Standort Bemerkung'] = [remove_line(x) for x in df['Standort Bemerkung']]
df['Standort Bemerkung'] = [remove_space(x) for x in df['Standort Bemerkung']]
#df['Standort Bemerkung'] = [remove_additional(x) for x in df['Standort Bemerkung']]
df['Standort Bemerkung'] = [remove_additional(x) for x in df['Standort Bemerkung']]
print("typedf",type(df['Standort Bemerkung']))
#df.drop(df['Standort Bemerkung'].index[2],inplace=True)
#np.toarray(df['Standort Bemerkung'])
array = []
for i in range(len(df['Standort Bemerkung'])):
    if len(df['Standort Bemerkung'].iloc[i]) <= 64:
        array.append(i)
    print("len!",len((df['Standort Bemerkung'].iloc[i])))
    print("dfi!",(df['Standort Bemerkung'].iloc[i]))
df = df.reset_index()
df.drop(array,inplace=True)
#df['Standort Bemerkung'] = [remove_additional(x) for x in df['Standort Bemerkung']]
#df.drop(colums = 'index',inplace=True)

#df.rename(columns={"Standort Bemerkung": "a", "AIDA IP RG": "c"})
print(df.shape)
#print('df@@@@@@@@@',df)
df.drop(columns = ['index'],inplace=True)

df.drop(columns = ['Standort Name'],inplace=True)

# df.iloc[1,2] = 'Funtions'
# df.iloc[1,3] = 'Target ML'
# df.iloc[1,4] = 'JAP ML'
# df.iloc[1,5] = 'Detail'

# ###

# last_column = df.range(1, 1).end('right').get_address(0, 0)[0] #last colum
# last_row = df.range(1, 1).end('down').row #last row

# a_range = f'A1:{last_column}{last_row}' #生成表格的数据范围

# #setting frame
# df.range(a_range).api.Borders(8).LineStyle = 1 #上
# df.range(a_range).api.Borders(9).LineStyle = 1 #下
# df.range(a_range).api.Borders(7).LineStyle = 1 #左
# df.range(a_range).api.Borders(10).LineStyle = 1 #右
# df.range(a_range).api.Borders(12).LineStyle = 1 #内横
# df.range(a_range).api.Borders(11).LineStyle = 1 #内纵

#patth = r'C:\Users\明\Desktop\BMW\list_0507v3.xlsx'
patth = r'U:\BMW\list0509v2.xlsx'
df.to_excel(patth,index=None)
#to_pdf(df, filename="list7")
# Out:
# 1,2@@@@@@@@@                                  Name EN Reportelement AIDA IP RG Standort RG  \
# 6                                            ADAS ASIA        5-6           5
# 7               Acoustic request to audio control unit        5-6           5
# 15       Listen to AM/FM Radio  (Legacy < IDC Android)        5-6           5
# 24                                      Show Call List        5-6           5
# 30   Display & operation in the rear of entertainme...        5-6           5
# ..                                                 ...        ...         ...
# 405               Telephony via second customer device        5-6           5
# 410                                   Watch TV (Japan)        5-6           5
# 416                                  Traffic Info ASIA        5-6           5
# 428                                    Voice Interface        5-6           5
# 443                                       Guiding ASIA        5-6           5
#
#                                     Standort Bemerkung Standort Name
# 6    2022-03-28 : Okawara\n\n[MLI]\n\n[Top5 defects...           JAP
# 7    2022-03-25 : Iwataki\n\n[MLI]\n\n\n[Top5 defec...           JAP
# 15   2022-Mar-28, Iwataki\n\n[MLI]\n\n\n[Top5 defec...           JAP
# 24   2022-Mar-28: Iwataki\n\n[MLI]\n\n[Top5 defects...           JAP
# 30   2022-Mar-28, Iwataki\n\n[MLI]\n\n[Top5 defects...           JAP
# ..                                                 ...           ...
# 405  2022-Mar-28 Iwataki\n\n[MLI]\n\n[Top5 defects]...           JAP
# 410  2022-Mar-28, Iwataki\n\n[MLI]\n\n\n[Top5 defec...           JAP
# 416  2022-04-04 : Takahiro Nagai\n\n[MLI]\n\n[Top5 ...           JAP
# 428  2022-03-25 : Iwataki\n\n[MLI]\n\n[Top5 defects...           JAP
# 443  2022-04-04:Takahiro Nagai\n\n[MLI]\n\n[Top5 de...           JAP
#
# [70 rows x 5 columns]
# 1,2@@@@@@@@@ 5-6
# 6      \n\n[MLI]\n\n[Top5 defects]\n\n–––––––––––––––...
# 7      \n\n[MLI]\n\n\n[Top5 defects]\n\n–––––––––––––...
# 15     \n\n[MLI]\n\n\n[Top5 defects]\n904258 [JP][MGU...
# 24     \n\n[MLI]\n\n[Top5 defects]\n\n\n\n–––––––––––...
# 30     \n\n[MLI]\n\n[Top5 defects]\n\n\n–––––––––––––...
#                              ...
# 405    \n\n[MLI]\n\n[Top5 defects]\n\n\n[Device used ...
# 410    \n\n[MLI]\n\n\n[Top5 defects]\n877250 [MGU22][...
# 416    \n\n[MLI]\n\n[Top5 defects]\n896121 [CW07][JP]...
# 428    \n\n[MLI]\n\n[Top5 defects]\n938980 [JP][speec...
# 443    \n\n[MLI]\n\n[Top5 defects]\n945208 [JP][MGU22...
# Name: Standort Bemerkung, Length: 70, dtype: object
# yyyyyyyyy ['', '', '                       ']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['[Top5 defects]', '904258 [JP][MGU22] no audio after a bus sleep  BI5/spor│KW08 > Duplicate to 906683 > 08-In Verification', '', '                     \u200b']
# yyyyyyyyy ['', '                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['', '', '[MLI]', '918697 [jp][mgu22] FireTV stuck on language`s settings BI4/rep | CW09 (SS candidate) > 04-In Progress', '', '[Top5 defects]', '907516 [JP][MGU22] PaDi does not respond correctly to touch command BI5/hint | CW08 (SS candidate) > 04-In Progress', '', '                     \u200b']
# yyyyyyyyy ['', '                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['', '', '                     \u200b']
# yyyyyyyyy ['[Top5 defects]', '917865 [jp][mgu22] Fast/backward function is not working with USB iAP BI6/repr| CW09 > Duplicate to 896143 > 04-In Progress                     \u200b']
# yyyyyyyyy ['                       ']
# yyyyyyyyy ['', '', '                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['', '', '                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['[Top5 defects]', '861140 [XMAS][jp][mgu22][CarPlay] Intermediate destination cannot be deleted (google map) BI6/rep | CW02 > 04- In Progress', '811558 [JP][MGU22][CarPlay] Fast forward/backward is not possible BI5/rep | CW46  (No SS) > 04-In Progress', '', '[Device used for testing]', 'iPhone 11                                           │SW.: iOS 15.3.1', '', '                     \u200b']
# yyyyyyyyy ['', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '', '                     \u200b']
# yyyyyyyyy ['[Device used for testing]                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['Takano', '[Top5 defects]', '                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['[Top5 defects]', '894957    Weather app date format changes when selected a day.      BI6/rep    |   CW07', '                     \u200b']
# yyyyyyyyy ['', '                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['Takano', '                       ']
# yyyyyyyyy ['', '', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '', '[MLI]', '947163  [id8][jp][padi]amazon fire tv: login failure and cyclic login loop processes   BI5/rep   |   CW12', '', '[Top5 defects]', '858350 [jp][mgu22][PaDi] Keyboard input is not working correctly BI5/rep | CW03 (SS confirmed) > 08-In Verification', '', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '', '[MLI]', '947163  [id8][jp][padi]amazon fire tv: login failure and cyclic login loop processes   BI5/rep   |   CW12', '', '[Top5 defects]', '858350 [jp][mgu22][PaDi] Keyboard input is not working correctly BI5/rep | CW03 (SS confirmed) > 08-In Verification', '', '                     \u200b']
# yyyyyyyyy ['', '', '[MLI]', '947163  [id8][jp][padi]amazon fire tv: login failure and cyclic login loop processes   BI5/rep   |   CW12', '', '[Top5 defects]', '907516 [JP][MGU22] PaDi does not respond correctly to touch command BI5/hint | CW08 (SS candidate) > 04-In Progress', '858350 [jp][mgu22][PaDi] Keyboard input is not working correctly BI5/rep | CW03 (SS confirmed) > 08-In Verification[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '[Top5 defects]', '917696 Copy of [jp][mgu22][bmt] Index letter is not shown when scrolling through the same contacts BI6/rep | CW08 (No SS) > 04 In Progress', '', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['                     \u200b']
# yyyyyyyyy ['Nagai', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '', '                       ']
# yyyyyyyyy ['', '', '[Top5 defects]', '907284 [jp][mgu22][bmt] Index letter is not shown when scrolling through the same contacts BI6/rep | CW08 ', '(Master ticket 917696 Copy of [jp][mgu22][bmt] Index letter is not shown when scrolling through the same contacts) > 04-In Progress', '', '                     \u200b']
# yyyyyyyyy ['', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '', '[MLI]', '938087[JP][MGU22] not possible to set navigation destination from telephone number search results  BI5/repr│KW11 -> 906016 > 04 In Progress > Reproduced', '934969 [JP][MGU22] not possible to set navigation destination from contacts  BI5/repr│KW11 -> 922817 >08-In Progress (CW14) > Reproduced', '', '                       ']
# yyyyyyyyy ['', '', '[Top5 defects]', '740208 [JP][MGU22] corrupted graphic appears when setting a destination  BI5/repr│KW35 > 04 In progress > Not reproduced', '                       ']
# yyyyyyyyy ['Takano', '[Top5 defects]', '944124 [MGU22] All ConnectedDrive OAP Apps missing on G70 rack BI4/Repr CW12', '883557 [JP][Alexa] Paying media is not switched by speech command with Alexa BI5/Repr CW6', '925104 [JP][Weather] Weather app is not selectable BI5/HIgh CW11', '941410 [JP] YouTube app is frequently not available BI5/High CW12', '(ticket will be created) [JP] Cannot proceed Alexa setup in the page of sign in process BI5/High CW13', '----------------------------------------------------------------------']
# yyyyyyyyy ['', '[Top5 defects]', '907516 [JP][MGU22] PaDi does not respond correctly to touch command BI5/hint | CW08 (SS candidate) > 04-In Progress', '', '                     \u200b']
# yyyyyyyyy ['', '', '[MLI]', '947163  [id8][jp][padi]amazon fire tv: login failure and cyclic login loop processes   BI5/rep   |   CW12', '', '[Top5 defects]', '907516 [JP][MGU22] PaDi does not respond correctly to touch command BI5/hint | CW08 (SS candidate) > 04-In Progress', '858350 [jp][mgu22][PaDi] Keyboard input is not working correctly BI5/rep | CW03 (SS confirmed) > 08-In Progress', '', '[Device used for testing]                     \u200b']
# yyyyyyyyy ['', '', '[Top5 defects]', '922665 [JP][MGU22][PU2307] Charge stations search shows no result when online POI is active   BI5/repr│KW10 > 04 In Progress > Reproduced', '894712 [MAP][JP][CW07] Preview map of POI results not working  BI5/spor│KW07 -> 892693 > 08-In Verification > Not reproduced', '740208 [JP][MGU22] corrupted graphic appears when setting a destination  BI5/repr│KW34 > 04 In Progress > Not reproduced', '                       ']
# yyyyyyyyy ['', '', '[Top5 defects]', '894744 [CW07][JP][POS] CCP drifts in Aqua tunnel (Chiba to Tokyo)  BI5/sing│KW07 > 04 In Progress (Target week CW15)', '', '                       ']
# yyyyyyyyy ['Takano', '                       ']
# yyyyyyyyy ['', '', '[Top5 defects] ', '916693 [JP][MGU22] sort destinations does not work  BI5/repr│KW09 > 08 In verification > not reproduced and ticket will be closed.', '', '                       ']
# yyyyyyyyy ['', '', '[Device used for testing]', 'Galaxy S21 5G', 'iPhone SE            iOS 15.3.1', '', '                     \u200b']
# yyyyyyyyy ['[Device used for testing]', '', '                     \u200b']
# yyyyyyyyy ['[Top5 defects]', '894988 [CW07][JP]outgoing call by voice dial number not possible BI5/spor | CW06 > 04 In Progress', '804843 [JP][MGU22] Conference call status is not updated on CID   BI6/rep | CW46 > 03 In Analysis', '[Device used for test]', '                     \u200b']
# yyyyyyyyy ['[Device used for testing]                     \u200b']
# yyyyyyyyy ['[Top5 defects]', '877250 [MGU22][JP][tv] Focus bar jumps on wrong entry BI6/rep | CW04 > 04-In Progress', '878239 [MGU22][JP][tv] Station title`s overlay continues popping up BI6/rep | CW04 > 04-In Progress', '                     \u200b']
# yyyyyyyyy ['', '', '[Top5 defects]', '896121 [CW07][JP][TI] No CHM displayed in Traffic widget   BI5/high  │ KW07 > 04 In Progress (Target week CW15) > Reproduced', '                       ']
# yyyyyyyyy ['', '', '[Top5 defects]', '938980 [JP][speech]voice command "Theatre Screen" not recognized   BI6/rep   |  CW11', '878470 1-shot address/ poi search: No search started even dictated search token displayed on top of CID for a moment.   BI5/spo  |   CW04', '806111 [CW45][JP][MGU22][Speech] TV station is not recognized via speech   BI5/rep | CW45                     \u200b']
# yyyyyyyyy ['', '', '[Top5 defects]', '945208 [JP][MGU22] no route line in Kombi map widget although route guidance is active  BI6/spor│KW12 > 04 In Progress', '894747 [CW07][JP][GUIDA] Wrong utterance in Japanese at all motorway Junction  BI5/repr│KW07 > 04 In Progress', '                       ']
# typedf <class 'pandas.core.series.Series'>
# len! 3
# dfi!                          0
# 0
# 1
# 2
# len! 1
# dfi!                         0
# 0                       ​
# len! 4
# dfi!                                                    0
# 0                                     [Top5 defects]
# 1  904258 [JP][MGU22] no audio after a bus sleep ...
# 2
# 3                                                  ​
# len! 2
# dfi!                         0
# 0
# 1                       ​
# len! 1
# dfi!                         0
# 0                       ​
# len! 9
# dfi!                                                    0
# 0
# 1
# 2                                              [MLI]
# 3  918697 [jp][mgu22] FireTV stuck on language`s ...
# 4
# 5                                     [Top5 defects]
# 6  907516 [JP][MGU22] PaDi does not respond corre...
# 7
# 8                                                  ​
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-327-4b76ce5bcf74> in <module>
#      32 array = []
#      33 for i in range(len(df['Standort Bemerkung'])):
# ---> 34     if len(df['Standort Bemerkung'].iloc[i]) <= 64:
#      35         array.append(i)
#      36     print("len!",len((df['Standort Bemerkung'].iloc[i])))
#
# TypeError: object of type 'NoneType' has no len()
